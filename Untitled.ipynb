# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib

server = "pm-predictive-maintenance.database.windows.net"
database = "predictive-maintenance-db"
username = "Akshad2000"
password = "Ritik2000"
driver = "{ODBC Driver 18 for SQL Server}"

params = urllib.parse.quote_plus(
    f"DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}"
)
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")
print(f"DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD=****")
print("Actual server value:", repr(server))
print("Actual username value:", repr(username))
# load your local CSVs
equipment_master = pd.read_csv("data/sap_equipment_master.csv")
sap_production = pd.read_csv("data/sap_production.csv")
sap_downtime = pd.read_csv("data/sap_downtime.csv")

# push each one to Azure SQL as a table
equipment_master.to_sql("equipment_master", engine, if_exists="replace", index=False)
sap_production.to_sql("sap_production", engine, if_exists="replace", index=False)
sap_downtime.to_sql("sap_downtime", engine, if_exists="replace", index=False)

print("Upload complete")
# Out:
# DRIVER={ODBC Driver 18 for SQL Server};SERVER=pm-predictive-maintenance.database.windows.net;DATABASE=predictive-maintenance-db;UID=Akshad2000;PWD=****
# Actual server value: 'pm-predictive-maintenance.database.windows.net'
# Actual username value: 'Akshad2000'
# Upload complete
